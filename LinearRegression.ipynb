# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn import linear_model

# %%
x =  pd.read_csv("C:\\Users\\kisha\\Downloads\\homeprices (2).csv")
x
# Out:
#    area   price
# 0  2600  550000
# 1  3000  565000
# 2  3200  610000
# 3  3600  680000
# 4  4000  725000

# %%
plt.xlabel('area')
plt.ylabel('price(USD)')
plt.scatter(x.area,x.price,color = 'red', marker = '*')

# %%
plt.xlabel('area')
plt.ylabel('price(USD)')
plt.scatter(x.area,x.price,color = 'red', marker = '*')
plt.plot(x.area,rex.predict(x[['area']]),color ='purple')

# %%
rex = linear_model.LinearRegression()

# %%
rex.fit(x[['area']],x.price)
# Out:
# LinearRegression()

# %%
rex.predict([[3100]])
# Out:
# C:\Users\kisha\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([601558.21917808])

# %%
area_df = pd.read_csv("C:\\Users\\kisha\\Downloads\\areas (1).csv")
area_df.head()
# Out:
#    area
# 0  1000
# 1  1500
# 2  2300
# 3  3540
# 4  4120

# %%
p = rex.predict(area_df)
p
# Out:
# array([ 316404.10958904,  384297.94520548,  492928.08219178,
#         661304.79452055,  740061.64383562,  799808.21917808,
#         926090.75342466,  650441.78082192,  825607.87671233,
#         492928.08219178, 1402705.47945205, 1348390.4109589 ,
#        1144708.90410959])

# %%
area_df['price'] = p
area_df
# Out:
#     area         price
# 0   1000  3.164041e+05
# 1   1500  3.842979e+05
# 2   2300  4.929281e+05
# 3   3540  6.613048e+05
# 4   4120  7.400616e+05
# 5   4560  7.998082e+05
# 6   5490  9.260908e+05
# 7   3460  6.504418e+05
# 8   4750  8.256079e+05
# 9   2300  4.929281e+05
# 10  9000  1.402705e+06
# 11  8600  1.348390e+06
# 12  7100  1.144709e+06

# %%
area_df.to_csv("prediction.csv")

# %% [markdown]
# EXERCISE

# %%
z =  pd.read_csv("C:\\Users\\kisha\\Downloads\\canada_per_capita_income (1).csv")
z.head()
# Out:
#    year          xyz
# 0  1970  3399.299037
# 1  1971  3768.297935
# 2  1972  4251.175484
# 3  1973  4804.463248
# 4  1974  5576.514583

# %%
rez = linear_model.LinearRegression()

# %%
rez.fit(z[['year']],z.xyz)
# Out:
# LinearRegression()

# %%
rez.predict([[2020]])
# Out:
# C:\Users\kisha\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([41288.69409442])
